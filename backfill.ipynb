# %%
from datetime import datetime
from app.service.backfill_service import BackfillService

start_timestamp = datetime.fromisoformat("2025-05-03T00:00:00Z".strip().replace("Z", "+00:00"))
end_timestamp = datetime.fromisoformat("2025-05-04T00:00:00Z".replace("Z", "+00:00"))
service = BackfillService("binance")
service.run(start_timestamp, end_timestamp, "BTC/USDT", "1h")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       5 end_timestamp = datetime.fromisoformat("2025-05-04T00:00:00Z".replace("Z", "+00:00"))
#       6 service = BackfillService("binance")
# ----> 7 service.run(start_timestamp, end_timestamp, "BTC/USDT", "1h")
#
# File F:\hackathon\solana startup terminal\klines-service\app\service\backfill_service.py:12, in BackfillService.run(self, start_timestamp, end_timestamp, symbol, timeframe)
#      11 def run(self, start_timestamp: datetime, end_timestamp: datetime,symbol: str, timeframe: str):
# ---> 12     self.adapter.backfill_ohlcv(start_timestamp, end_timestamp, symbol, timeframe)
#
# File F:\hackathon\solana startup terminal\klines-service\app\adapters\implementations\binance.py:84, in BinanceAdapter.backfill_ohlcv(self, start_date, end_date, symbol, timeframe)
#      81     session.bulk_save_objects(rows)
# ...

# %%
print ("Hello from Jupyter")
