# %%
import pandas as pd

df = pd.read_csv('http://localhost:8000/ohlcv?start_time=2024-01-01T00%3A00%3A00Z&end_time=2024-01-02T00%3A00%3A00Z&exchange=binance&symbol=SOLUSDT&timeframe=1m&response_format=csv')
df
# Out:
#                       timestamp exchange   symbol timeframe    open    high  \
# 0     2024-01-01 00:00:00+00:00  binance  SOLUSDT        1m  101.72  101.81
# 1     2024-01-01 00:01:00+00:00  binance  SOLUSDT        1m  101.71  101.92
# 2     2024-01-01 00:02:00+00:00  binance  SOLUSDT        1m  101.89  102.13
# 3     2024-01-01 00:03:00+00:00  binance  SOLUSDT        1m  102.13  102.31
# 4     2024-01-01 00:04:00+00:00  binance  SOLUSDT        1m  102.27  102.43
# ...                         ...      ...      ...       ...     ...     ...
# 1435  2024-01-01 23:55:00+00:00  binance  SOLUSDT        1m  109.38  109.46
# 1436  2024-01-01 23:56:00+00:00  binance  SOLUSDT        1m  109.45  109.50
# 1437  2024-01-01 23:57:00+00:00  binance  SOLUSDT        1m  109.44  109.50
# 1438  2024-01-01 23:58:00+00:00  binance  SOLUSDT        1m  109.47  109.67
# 1439  2024-01-01 23:59:00+00:00  binance  SOLUSDT        1m  109.50  109.93
#
#          low   close    volume
# ...
